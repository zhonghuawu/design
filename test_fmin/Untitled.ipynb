# %%
import matplotlib.pyplot as plt
import numpy as np
import mpl_tookits.mplot3d
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-87bdf020774f> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 import mpl_tookits.mplot3d
#
# ImportError: No module named mpl_tookits.mplot3d
